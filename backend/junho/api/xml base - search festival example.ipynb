# %%
import requests
import pandas as pd
from pymongo import MongoClient
from bs4 import BeautifulSoup
import numpy as np

# %%
# xml base - search festival example
operation = ['areaCode','categoryCode','areaBasedList','locationBasedList','searchKeyword',
            'searchFestival','searchStay','detailCommon','detailIntro','detailInfo','detailImage']

numOfRows = '1051' # 최대길이
areaCode = '1' # 서울
eventStartDate = '20220101'
sigunguCode = '1' # 강남구

url = f'http://api.visitkorea.or.kr/openapi/service/rest/KorService/searchFestival'
key = '?ServiceKey=S256yGjpf7ug3eDtNRoJBzPLPIED9Mzp3XfMp8aaoRB/FGnDuzloLHkpvLvTyddzf00SKndA/1naWcmH2ao5jg=='
option = f'&numOfRows={numOfRows}&areaCode={areaCode}&eventStartDate={eventStartDate}&sigunguCode={sigunguCode}&MobileOS=ETC&MobileApp=AppTest&_type=json'
response = requests.get(url+key+option)

# xml_obj = BeautifulSoup(response.content,'lxml-xml')
# tp = xml_obj.find_all('item')
# columns = [tp[0].find_all()[i].name for i in range(len(tp[0]))]

# import numpy as np
# pd.DataFrame(np.array(tp).squeeze(),columns=columns)

# %%
response.headers
# Out:
# {'Date': 'Tue, 12 Jul 2022 07:56:14 GMT', 'Server': 'Apache', 'Access-Control-Allow-Origin': '*', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked'}

# %%
data = response.json()

# %%
data['response']['body']['items']['item']
# Out:
# [{'addr1': '서울특별시 강남구 논현동',
#   'addr2': '논현동 가구거리',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0208',
#   'cat3': 'A02080600',
#   'contentid': 2819403,
#   'contenttypeid': 15,
#   'createdtime': 20220511162910,
#   'eventenddate': 20220904,
#   'eventstartdate': 20220826,
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/96/2819396_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/96/2819396_image2_1.jpg',
#   'mapx': 127.0225157989,
#   'mapy': 37.5112531257,
#   'mlevel': 6,
#   'modifiedtime': 20220511163759,
#   'readcount': 0,
#   'sigungucode': 1,
#   'tel': '02-3423-5532',
#   'title': '강남인테리어디자인위크'},
#  {'addr1': '서울특별시 강남구 영동대로 513',
#   'addr2': '(삼성동)',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0208',
#   'cat3': 'A02080600',
#   'contentid': 1276136,
#   'contenttypeid': 15,
#   'createdtime': 20110512192643,
#   'eventenddate': 20220605,
#   'eventstartdate': 20220602,
#   'mapx': 127.0594124394,
#   'mapy': 37.5112648981,
#   'mlevel': 6,
#   'modifiedtime': 20220614170520,
#   'readcount': 31761,
#   'sigungucode': 1,
#   'tel': '02-6000-8000',
#   'title': '국제차문화대전'},
#  {'addr1': '서울특별시 강남구  논현로 (134, 연산MS)',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0208',
#   'cat3': 'A02081300',
#   'contentid': 2804687,
#   'contenttypeid': 15,
#   'createdtime': 20220117174057,
#   'eventenddate': 20220312,
#   'eventstartdate': 20220312,
#   'mapx': 127.0433813981,
#   'mapy': 37.4818569134,
#   'mlevel': 6,
#   'modifiedtime': 20220208163537,
#   'readcount': 0,
#   'sigungucode': 1,
#   'tel': '070-8892-9645',
#   'title': '무브컬쳐 축제학교 시즌2: 우리의 문화기획 스토리'},
#  {'addr1': '서울특별시 강남구 남부순환로 3104',
#   'addr2': '(대치동)',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0207',
#   'cat3': 'A02070200',
#   'contentid': 2658426,
#   'contenttypeid': 15,
#   'createdtime': 20200604103329,
#   'eventenddate': 20210220,
#   'eventstartdate': 20220218,
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/23/2658423_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/23/2658423_image2_1.jpg',
#   'mapx': 127.0719811806,
#   'mapy': 37.4957363721,
#   'mlevel': 6,
#   'modifiedtime': 20210831130053,
#   'readcount': 0,
#   'sigungucode': 1,
#   'tel': '02-2223-1853',
#   'title': '비건페스타'},
#  {'addr1': '서울특별시 강남구 영동대로 513 코엑스',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0208',
#   'cat3': 'A02080600',
#   'contentid': 1024038,
#   'contenttypeid': 15,
#   'createdtime': 20100518222522,
#   'eventenddate': 20220626,
#   'eventstartdate': 20220623,
#   'mapx': '127.0592179950',
#   'mapy': 37.5119175967,
#   'mlevel': 6,
#   'modifiedtime': 20220526175014,
#   'readcount': 16099,
#   'sigungucode': 1,
#   'tel': '02-757-6161',
#   'title': '서울국제관광전'},
#  {'addr1': '서울특별시 강남구  영동대로 (513, 코엑스)',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0208',
#   'cat3': 'A02080500',
#   'contentid': 228985,
#   'contenttypeid': 15,
#   'createdtime': 20070529090000,
#   'eventenddate': 20220605,
#   'eventstartdate': 20220601,
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/56/2639256_image2_1.JPG',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/56/2639256_image2_1.JPG',
#   'mapx': 127.0594429796,
#   'mapy': 37.5117148467,
#   'mlevel': 6,
#   'modifiedtime': 20220125101545,
#   'readcount': 165277,
#   'sigungucode': 1,
#   'tel': '02-7333-8402',
#   'title': '서울국제도서전'},
#  {'addr1': '서울특별시 강남구 영동대로 513 코엑스 B홀',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0208',
#   'cat3': 'A02081300',
#   'contentid': 1778398,
#   'contenttypeid': 15,
#   'createdtime': 20130110175909,
#   'eventenddate': 20220702,
#   'eventstartdate': 20220630,
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/65/2775865_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/65/2775865_image2_1.jpg',
#   'mapx': 127.0591874466,
#   'mapy': 37.5117592813,
#   'mlevel': 6,
#   'modifiedtime': 20211229135531,
#   'readcount': 2095,
#   'sigungucode': 1,
#   'tel': '02-761-2516',
#   'title': '서울국제주류&와인박람회'},
#  {'addr1': '서울특별시 강남구 봉은사로63길 35',
#   'addr2': '(삼성동)',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0208',
#   'cat3': 'A02080500',
#   'contentid': 2718984,
#   'contenttypeid': 15,
#   'createdtime': 20210601221819,
#   'eventenddate': 20220710,
#   'eventstartdate': 20220707,
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/14/2814214_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/14/2814214_image2_1.jpg',
#   'mapx': 127.0462413481,
#   'mapy': 37.5136810472,
#   'mlevel': 6,
#   'modifiedtime': 20220329131812,
#   'readcount': 0,
#   'sigungucode': 1,
#   'tel': 'support@seoulillustrationfair.co.kr',
#   'title': '서울일러스트레이션페어V.13'},
#  {'addr1': '서울특별시 강남구  영동대로 (513, 코엑스)',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0208',
#   'cat3': 'A02081300',
#   'contentid': 2805957,
#   'contenttypeid': 15,
#   'createdtime': 20220203161945,
#   'eventenddate': 20221126,
#   'eventstartdate': 20221123,
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/41/2805941_image2_1.JPG',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/41/2805941_image2_1.JPG',
#   'mapx': 127.0594429796,
#   'mapy': 37.5117148467,
#   'mlevel': 6,
#   'modifiedtime': 20220214171448,
#   'readcount': 0,
#   'sigungucode': 1,
#   'tel': '02-6000-6698',
#   'title': '제11회 월드커피리더스포럼'},
#  {'addr1': '서울특별시 강남구 영동대로 513',
#   'addr2': '(삼성동)',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0207',
#   'cat3': 'A02070200',
#   'contentid': 2732352,
#   'contenttypeid': 15,
#   'createdtime': 20210809231735,
#   'eventenddate': 20220506,
#   'eventstartdate': 20220502,
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/65/2756765_image2_1.png',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/65/2756765_image2_1.png',
#   'mapx': 127.0594429796,
#   'mapy': 37.5117148467,
#   'mlevel': 6,
#   'modifiedtime': 20220307160753,
#   'readcount': 0,
#   'sigungucode': 1,
#   'tel': '02-6000-7275',
#   'title': '제15차 세계산림총회'},
#  {'addr1': '서울특별시 강남구 영동대로 513',
#   'addr2': '(삼성동)',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0208',
#   'cat3': 'A02081300',
#   'contentid': 2714158,
#   'contenttypeid': 15,
#   'createdtime': 20210421021133,
#   'eventenddate': 20220227,
#   'eventstartdate': 20220223,
#   'mapx': 127.0594429796,
#   'mapy': 37.5117148467,
#   'mlevel': 6,
#   'modifiedtime': 20220223170407,
#   'readcount': 0,
#   'sigungucode': 1,
#   'tel': '02-2262-7194',
#   'title': '제27회 서울리빙디자인페어'},
#  {'addr1': '서울특별시 강남구  영동대로 (513, 코엑스)',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0207',
#   'cat3': 'A02070200',
#   'contentid': 2805988,
#   'contenttypeid': 15,
#   'createdtime': 20220204090941,
#   'eventenddate': 20221126,
#   'eventstartdate': 20221123,
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/49/2806349_image2_1.png',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/49/2806349_image2_1.png',
#   'mapx': 127.0594429796,
#   'mapy': 37.5117148467,
#   'mlevel': 6,
#   'modifiedtime': 20220209164855,
#   'readcount': 0,
#   'sigungucode': 1,
#   'tel': '02-6000-6709',
#   'title': '제7회 서울커피페스티벌 The 7th Seoul Coffee Festival'},
#  {'addr1': '서울특별시 강남구 영동대로 513',
#   'addr2': '(삼성동)',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0208',
#   'cat3': 'A02080500',
#   'contentid': 2804204,
#   'contenttypeid': 15,
#   'createdtime': 20211229113120,
#   'eventenddate': 20220710,
#   'eventstartdate': 20220708,
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/02/2804202_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/02/2804202_image2_1.jpg',
#   'mapx': 127.0594429796,
#   'mapy': 37.5117148467,
#   'mlevel': 6,
#   'modifiedtime': 20211229113120,
#   'readcount': 0,
#   'sigungucode': 1,
#   'tel': '02-761-2512',
#   'title': '코리아비건페어 2022'},
#  {'addr1': '서울특별시 강남구 영동대로 513',
#   'addr2': '(삼성동)',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0207',
#   'cat3': 'A02070200',
#   'contentid': 622888,
#   'contenttypeid': 15,
#   'createdtime': 20080911194541,
#   'eventenddate': 20220906,
#   'eventstartdate': 20220903,
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/99/565999_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/99/565999_image3_1.jpg',
#   'mapx': 127.0591318945,
#   'mapy': 37.5118092746,
#   'mlevel': 6,
#   'modifiedtime': 20220518102408,
#   'readcount': 22898,
#   'sigungucode': 1,
#   'tel': '02-733-3706',
#   'title': '한국국제아트페어'},
#  {'addr1': '서울특별시 강남구 영동대로 513 코엑스',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0207',
#   'cat3': 'A02070200',
#   'contentid': 1066064,
#   'contenttypeid': 15,
#   'createdtime': 20100729201821,
#   'eventenddate': 20220925,
#   'eventstartdate': 20220925,
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/26/2822726_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/26/2822726_image3_1.jpg',
#   'mapx': '127.0592179950',
#   'mapy': 37.5119175967,
#   'mlevel': 6,
#   'modifiedtime': 20220603145908,
#   'readcount': 22898,
#   'sigungucode': 1,
#   'tel': '02-702-7775',
#   'title': '한일축제한마당 in Seoul'},
#  {'addr1': '서울특별시 강남구 영동대로 513',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0208',
#   'cat3': 'A02080500',
#   'contentid': 2656669,
#   'contenttypeid': 15,
#   'createdtime': 20200519224845,
#   'eventenddate': 20220611,
#   'eventstartdate': 20220609,
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/25/2815125_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/25/2815125_image2_1.jpg',
#   'mapx': 127.0594429796,
#   'mapy': 37.5117148467,
#   'mlevel': 6,
#   'modifiedtime': 20220406113045,
#   'readcount': 0,
#   'sigungucode': 1,
#   'tel': '02-881-5151',
#   'title': '홈케어·재활·복지 전시회 Reha·Homecare'},
#  {'addr1': '서울특별시 강남구 남부순환로 3104',
#   'addr2': '(대치동)',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0208',
#   'cat3': 'A02080600',
#   'contentid': 2620577,
#   'contenttypeid': 15,
#   'createdtime': 20190923231449,
#   'eventenddate': 20221002,
#   'eventstartdate': 20220929,
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/79/2823779_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/79/2823779_image3_1.jpg',
#   'mapx': 127.0719811806,
#   'mapy': 37.4957363721,
#   'modifiedtime': 20220620100832,
#   'readcount': 0,
#   'sigungucode': 1,
#   'tel': '02-2231-2013',
#   'title': '2022서울국제불교박람회'},
#  {'addr1': '서울특별시 강남구 남부순환로 3104 SETEC',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0207',
#   'cat3': 'A02070200',
#   'contentid': 2755544,
#   'contenttypeid': 15,
#   'createdtime': 20211012222239,
#   'eventenddate': 20221031,
#   'eventstartdate': 20220801,
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/40/2755540_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/40/2755540_image2_1.jpg',
#   'mapx': 127.0707673919,
#   'mapy': 37.4960890861,
#   'mlevel': 6,
#   'modifiedtime': 20220629112835,
#   'readcount': 0,
#   'sigungucode': 1,
#   'tel': '02-2231-2011',
#   'title': '2022서울릴랙스위크'},
#  {'addr1': '서울특별시 강남구 봉은사로 524',
#   'addr2': '(삼성동)',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0208',
#   'cat3': 'A02081300',
#   'contentid': 2802854,
#   'contenttypeid': 15,
#   'createdtime': 20211227101455,
#   'eventenddate': 20220120,
#   'eventstartdate': 20220120,
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/53/2802853_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/53/2802853_image2_1.jpg',
#   'mapx': 127.0573070288,
#   'mapy': '37.5129313340',
#   'mlevel': 6,
#   'modifiedtime': 20211227101455,
#   'readcount': 0,
#   'sigungucode': 1,
#   'tel': '02-961-2580',
#   'title': '2022 산림・임업 전망 발표대회'},
#  {'addr1': '서울특별시 강남구 영동대로 513',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0208',
#   'cat3': 'A02080500',
#   'contentid': 1364529,
#   'contenttypeid': 15,
#   'createdtime': 20110816165902,
#   'eventenddate': 20221126,
#   'eventstartdate': 20221123,
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/49/2801549_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/49/2801549_image2_1.jpg',
#   'mapx': 127.0591874466,
#   'mapy': 37.5117592813,
#   'mlevel': 6,
#   'modifiedtime': 20211217154552,
#   'readcount': 20997,
#   'sigungucode': 1,
#   'tel': '02-6000-6709',
#   'title': '2022 서울카페쇼'},
#  {'addr1': '서울특별시 강남구 영동대로 513',
#   'addr2': '(삼성동)',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0208',
#   'cat3': 'A02080500',
#   'contentid': 1574767,
#   'contenttypeid': 15,
#   'createdtime': 20120322233609,
#   'eventenddate': 20220402,
#   'eventstartdate': 20220330,
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/27/2810427_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/27/2810427_image2_1.jpg',
#   'mapx': '127.0593429860',
#   'mapy': 37.5118037234,
#   'mlevel': 6,
#   'modifiedtime': 20220314100258,
#   'readcount': 18140,
#   'sigungucode': 1,
#   'tel': '02-6000-1422/8155',
#   'title': '2022 서울커피엑스포'},
#  {'addr1': '서울특별시 강남구  선릉로111길 (33)',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0208',
#   'cat3': 'A02080900',
#   'contentid': 2807072,
#   'contenttypeid': 15,
#   'createdtime': 20220214110442,
#   'eventenddate': 20221231,
#   'eventstartdate': 20220101,
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/70/2807070_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/70/2807070_image2_1.jpg',
#   'mapx': 127.0409280431,
#   'mapy': 37.5101313642,
#   'mlevel': 6,
#   'modifiedtime': 20220214110548,
#   'readcount': 0,
#   'sigungucode': 1,
#   'tel': 'kpmakorea@aol.com',
#   'title': '2022 선한영향력가게와 함께하는 공익 캠페인 Korea Music Festival'},
#  {'addr1': '온라인개최',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0207',
#   'cat3': 'A02070200',
#   'contentid': 2642292,
#   'contenttypeid': 15,
#   'createdtime': 20191224143805,
#   'eventenddate': 20220101,
#   'eventstartdate': 20211231,
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/37/2804537_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/37/2804537_image2_1.jpg',
#   'mapx': 127.0594429796,
#   'mapy': 37.5117148467,
#   'mlevel': 6,
#   'modifiedtime': 20211231101903,
#   'readcount': 0,
#   'sigungucode': 1,
#   'tel': '02-751-9356',
#   'title': '2022 영동대로 카운트다운'},
#  {'addr1': '서울특별시 강남구 남부순환로 3104 SETEC',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0207',
#   'cat3': 'A02070200',
#   'contentid': 2376250,
#   'contenttypeid': 15,
#   'createdtime': 20160405222624,
#   'eventenddate': 20220515,
#   'eventstartdate': 20220514,
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/23/2814223_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/23/2814223_image2_1.jpg',
#   'mapx': 127.0707673919,
#   'mapy': 37.4960890861,
#   'mlevel': 6,
#   'modifiedtime': 20220329135328,
#   'readcount': 212953,
#   'sigungucode': 1,
#   'tel': '02-6010-8941',
#   'title': '28회 서울디저트페어 [감사축하전]'},
#  {'addr1': '서울특별시 강남구 영동대로 513 코엑스',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0208',
#   'cat3': 'A02080500',
#   'contentid': 2818221,
#   'contenttypeid': 15,
#   'createdtime': 20220428180752,
#   'eventenddate': 20220508,
#   'eventstartdate': 20220502,
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/20/2818220_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/20/2818220_image2_1.jpg',
#   'mapx': '127.0592179950',
#   'mapy': 37.5119175967,
#   'mlevel': 6,
#   'modifiedtime': 20220428180801,
#   'readcount': 0,
#   'sigungucode': 1,
#   'tel': '02-6000-1155',
#   'title': 'BLOSSOM THE HOPE 2022'},
#  {'addr1': '서울특별시 강남구 영동대로 513',
#   'addr2': '(삼성동)',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0208',
#   'cat3': 'A02081300',
#   'contentid': 2381938,
#   'contenttypeid': 15,
#   'createdtime': 20160503022604,
#   'eventenddate': 20221204,
#   'eventstartdate': 20221201,
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/98/2815098_image2_1.jpg',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/98/2815098_image2_1.jpg',
#   'mapx': 127.0591318945,
#   'mapy': 37.5118092746,
#   'mlevel': 6,
#   'modifiedtime': 20220412165730,
#   'readcount': 6449,
#   'sigungucode': 1,
#   'tel': '02-761-2512',
#   'title': 'K-핸드메이드페어 2022'},
#  {'addr1': '서울특별시 강남구 영동대로 513',
#   'addr2': '(삼성동)',
#   'areacode': 1,
#   'cat1': 'A02',
#   'cat2': 'A0208',
#   'cat3': 'A02080600',
#   'contentid': 2608900,
#   'contenttypeid': 15,
#   'createdtime': 20190703002528,
#   'eventenddate': 20220617,
#   'eventstartdate': 20220616,
#   'mapx': 127.0594429796,
#   'mapy': 37.5117148467,
#   'mlevel': 6,
#   'modifiedtime': 20220610113725,
#   'readcount': 0,
#   'sigungucode': 1,
#   'title': 'NextRise 2022, Seoul'}]

# %%
# # write
# my_client = MongoClient('mongodb://localhost:27017')
# mydb = my_client['yosul_lamp']
# mydb['programs'].insert_many(pd.DataFrame(response.json()['data']).to_dict('records'))

# # read
# my_client = MongoClient('mongodb://localhost:27017')
# mydb = my_client['yosul_lamp']
# pd.DataFrame(mydb['programs'].find()).drop('_id',axis=1)

# %% [markdown]
# 지역코드 불분명
#
# 시군구코드 불분명
#
# cat1,cat2,cat3 분류코드 불분명
#
# - 지역 제한된 어플리케이션 고려

# %% [markdown]
# # Tour API 호출

# %%
import requests

# %% [markdown]
# ### 1) 국문 관광정보 서비스

# %% [markdown]
# - 지역코드 조회

# %%
url = 'http://apis.data.go.kr/B551011/KorService/areaCode'
key = 'S256yGjpf7ug3eDtNRoJBzPLPIED9Mzp3XfMp8aaoRB/FGnDuzloLHkpvLvTyddzf00SKndA/1naWcmH2ao5jg=='
params ={'serviceKey' : key, 'pageNo' : '1', 'numOfRows' : '10000', 'MobileApp': 'AppTest', 'MobileOS': 'ETC', '_type' : 'json'}
response = requests.get(url, params=params)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()['response']['body']['items']['item']
# Out:
# [{'rnum': 1, 'code': '1', 'name': '서울'},
#  {'rnum': 2, 'code': '2', 'name': '인천'},
#  {'rnum': 3, 'code': '3', 'name': '대전'},
#  {'rnum': 4, 'code': '4', 'name': '대구'},
#  {'rnum': 5, 'code': '5', 'name': '광주'},
#  {'rnum': 6, 'code': '6', 'name': '부산'},
#  {'rnum': 7, 'code': '7', 'name': '울산'},
#  {'rnum': 8, 'code': '8', 'name': '세종특별자치시'},
#  {'rnum': 9, 'code': '31', 'name': '경기도'},
#  {'rnum': 10, 'code': '32', 'name': '강원도'},
#  {'rnum': 11, 'code': '33', 'name': '충청북도'},
#  {'rnum': 12, 'code': '34', 'name': '충청남도'},
#  {'rnum': 13, 'code': '35', 'name': '경상북도'},
#  {'rnum': 14, 'code': '36', 'name': '경상남도'},
#  {'rnum': 15, 'code': '37', 'name': '전라북도'},
#  {'rnum': 16, 'code': '38', 'name': '전라남도'},
#  {'rnum': 17, 'code': '39', 'name': '제주도'}]

# %%
areaCode = '31'
sigunCode = '15'
year = '2022'
url = f'http://apis.data.go.kr/B551011/KorService/searchFestival?numOfRows=100&pageNo=1&MobileOS=ETC&MobileApp=AppTest&serviceKey=S256yGjpf7ug3eDtNRoJBzPLPIED9Mzp3XfMp8aaoRB%2FFGnDuzloLHkpvLvTyddzf00SKndA%2F1naWcmH2ao5jg%3D%3D&_type=json&areaCode={areaCode}&sigunguCode={sigunCode}&eventStartDate={year}0101'
url
# Out:
# 'http://apis.data.go.kr/B551011/KorService/searchFestival?numOfRows=100&pageNo=1&MobileOS=ETC&MobileApp=AppTest&serviceKey=S256yGjpf7ug3eDtNRoJBzPLPIED9Mzp3XfMp8aaoRB%2FFGnDuzloLHkpvLvTyddzf00SKndA%2F1naWcmH2ao5jg%3D%3D&_type=json&areaCode=31&sigunguCode=15&eventStartDate=20220101'

# %%
response = requests.get(url)

# %%
response.json()
# Out:
# {'response': {'header': {'resultCode': '0000', 'resultMsg': 'OK'},
#   'body': {'items': {'item': [{'addr1': '경기도 안산시 상록구 성호로 131',
#       'addr2': '(이동)',
#       'booktour': '',
#       'cat1': 'A02',
#       'cat2': 'A0207',
#       'cat3': 'A02070200',
#       'contentid': '1810345',
#       'contenttypeid': '15',
#       'createdtime': '20130509011043',
#       'eventstartdate': '20220528',
#       'eventenddate': '20220529',
#       'firstimage': '',
#       'firstimage2': '',
#       'mapx': '126.8595305730',
#       'mapy': '37.3151090853',
#       'mlevel': '6',
#       'modifiedtime': '20220511171123',
#       'readcount': 22889,
#       'areacode': '31',
#       'sigungucode': '15',
#       'tel': '031-415-0041~2',
#       'title': '안산 성호문화제'},
#      {'addr1': '경기도 안산시 단원구 광덕대로 157',
#       'addr2': '(고잔동)',
#       'booktour': '',
#       'cat1': 'A02',
#       'cat2': 'A0207',
#       'cat3': 'A02070200',
#       'contentid': '513326',
#       'contenttypeid': '15',
# ...

# %% [markdown]
# - 지역기반 관광정보 조회

# %%
url = 'http://apis.data.go.kr/B551011/KorService/areaBasedList'
key = 'S256yGjpf7ug3eDtNRoJBzPLPIED9Mzp3XfMp8aaoRB/FGnDuzloLHkpvLvTyddzf00SKndA/1naWcmH2ao5jg=='
params ={'serviceKey' : key, 'pageNo' : '1', 'numOfRows' : '10000', 'MobileApp': 'AppTest', 'MobileOS': 'ETC', '_type' : 'json', 'listYN': 'Y', 'arrange': 'C'}
response = requests.get(url, params=params)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()['response']['body']['items']['item']
# Out:
# [{'addr1': '전라남도 고흥군 고흥로 1896',
#   'addr2': '',
#   'areacode': '38',
#   'booktour': '',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020100',
#   'contentid': '',
#   'contenttypeid': '39',
#   'createdtime': '20220804130606',
#   'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/91/2832491_image2_1.JPG',
#   'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/91/2832491_image3_1.JPG',
#   'mapx': '127.2931155634',
#   'mapy': '34.6177074041',
#   'mlevel': '6',
#   'modifiedtime': '20220905192557',
#   'readcount': 17,
#   'sigungucode': '2',
#   'tel': '',
#   'title': '관산식당',
#   'zipcode': '59537'},
#  {'addr1': '경상남도 고성군 고성읍 서외리',
#   'addr2': '중앙로15번길 62',
#   'areacode': '36',
#   'booktour': '',
#   'cat1': 'A05',
#   'cat2': 'A0502',
#   'cat3': 'A05020100',
#   'contentid': '2849070',
#   'contenttypeid': '39',
#   'createdtime': '20220905163041',
#   'firstimage': '',
#   'firstimage2': '',
#   'mapx': '128.3222219276',
# ...

# %% [markdown]
# ### 2) 관광 빅데이터

# %%
url = 'http://apis.data.go.kr/B551011/DataLabService/locgoRegnVisitrDDList'
key = 'S256yGjpf7ug3eDtNRoJBzPLPIED9Mzp3XfMp8aaoRB/FGnDuzloLHkpvLvTyddzf00SKndA/1naWcmH2ao5jg=='
params ={'serviceKey' : key, 'pageNo' : '1', 'numOfRows' : '10000', 'MobileApp': 'AppTest', 'MobileOS': 'ETC', '_type' : 'json', 'startYmd': '20210906', 'endYmd': '20210906'}
response = requests.get(url, params=params)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()['response']['body']['items']['item']
# Out:
# [{'signguCode': '11110',
#   'signguNm': '종로구',
#   'daywkDivCd': '1',
#   'daywkDivNm': '월요일',
#   'touDivCd': '1',
#   'touDivNm': '현지인(a)',
#   'touNum': '160447.0',
#   'baseYmd': '20210906'},
#  {'signguCode': '11110',
#   'signguNm': '종로구',
#   'daywkDivCd': '1',
#   'daywkDivNm': '월요일',
#   'touDivCd': '2',
#   'touDivNm': '외지인(b)',
#   'touNum': '277599.0',
#   'baseYmd': '20210906'},
#  {'signguCode': '11110',
#   'signguNm': '종로구',
#   'daywkDivCd': '1',
#   'daywkDivNm': '월요일',
#   'touDivCd': '3',
#   'touDivNm': '외국인(c)',
#   'touNum': '327.7099763273588',
#   'baseYmd': '20210906'},
#  {'signguCode': '11140',
#   'signguNm': '중구',
#   'daywkDivCd': '1',
#   'daywkDivNm': '월요일',
#   'touDivCd': '1',
#   'touDivNm': '현지인(a)',
#   'touNum': '171353.0',
#   'baseYmd': '20210906'},
#  {'signguCode': '11140',
#   'signguNm': '중구',
#   'daywkDivCd': '1',
#   'daywkDivNm': '월요일',
#   'touDivCd': '2',
#   'touDivNm': '외지인(b)',
#   'touNum': '294955.5',
# ...
